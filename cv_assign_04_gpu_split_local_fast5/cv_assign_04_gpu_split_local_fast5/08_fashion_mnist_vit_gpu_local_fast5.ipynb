# %% [markdown]
# # 08. fashion_mnist + vit
#
# This notebook runs only **fashion_mnist + vit** using locally prepared datasets. It uses the faster 5-corruption setup: gaussian_noise, motion_blur, fog, brightness, jpeg_compression.

# %%
import sys, subprocess
REQUIRED_PACKAGES = ['setuptools<81', 'timm>=1.0.15', 'imagecorruptions==1.1.2', 'datasets>=2.21.0', 'umap-learn>=0.5.6', 'scikit-learn>=1.5.1', 'scikit-image<0.20', 'pandas>=2.0.0', 'matplotlib>=3.8.0', 'tqdm>=4.66.0', 'kaggle>=1.7.4.5']
subprocess.check_call([sys.executable, "-m", "pip", "install", *REQUIRED_PACKAGES])
print("Package installation complete.")
# Out:
# Requirement already satisfied: setuptools<81 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (80.10.2)
# Requirement already satisfied: timm>=1.0.15 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (1.0.22)
# Requirement already satisfied: imagecorruptions==1.1.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: datasets>=2.21.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (4.5.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (0.5.11)
# Requirement already satisfied: scikit-learn>=1.5.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: scikit-image<0.20 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (0.19.3)
# Requirement already satisfied: pandas>=2.0.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: matplotlib>=3.8.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: tqdm>=4.66.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (4.66.5)
# Requirement already satisfied: kaggle>=1.7.4.5 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (1.7.4.5)
# Requirement already satisfied: Pillow>=5.4.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from imagecorruptions==1.1.2) (11.3.0)
# Requirement already satisfied: numpy>=1.16 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from imagecorruptions==1.1.2) (1.26.4)
# Requirement already satisfied: opencv-python>=3.4.5 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from imagecorruptions==1.1.2) (4.12.0)
# Requirement already satisfied: scipy>=1.2.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from imagecorruptions==1.1.2) (1.15.3)
# Requirement already satisfied: networkx>=2.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-image<0.20) (3.4.2)
# Requirement already satisfied: imageio>=2.4.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-image<0.20) (2.37.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-image<0.20) (2025.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-image<0.20) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /home/sajjan/.local/lib/python3.10/site-packages (from scikit-image<0.20) (25.0)
# Requirement already satisfied: torch in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from timm>=1.0.15) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from timm>=1.0.15) (0.21.0+cu124)
# Requirement already satisfied: pyyaml in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from timm>=1.0.15) (6.0.2)
# Requirement already satisfied: huggingface_hub in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from timm>=1.0.15) (0.36.0)
# Requirement already satisfied: safetensors in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from timm>=1.0.15) (0.6.2)
# Requirement already satisfied: filelock in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (3.18.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (0.4.0)
# Requirement already satisfied: requests>=2.32.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (0.28.1)
# Requirement already satisfied: xxhash in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from datasets>=2.21.0) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (2025.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (3.12.15)
# Requirement already satisfied: anyio in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from httpx<1.0.0->datasets>=2.21.0) (4.10.0)
# Requirement already satisfied: certifi in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from httpx<1.0.0->datasets>=2.21.0) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from httpx<1.0.0->datasets>=2.21.0) (1.0.9)
# Requirement already satisfied: idna in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from httpx<1.0.0->datasets>=2.21.0) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.21.0) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from huggingface_hub->timm>=1.0.15) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from huggingface_hub->timm>=1.0.15) (1.1.7)
# Requirement already satisfied: numba>=0.51.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from umap-learn>=0.5.6) (0.63.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from umap-learn>=0.5.6) (0.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=1.5.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=1.5.1) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from pandas>=2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from pandas>=2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from pandas>=2.0.0) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.8.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.8.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.8.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.8.0) (1.4.8)
# Requirement already satisfied: pyparsing>=3 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.8.0) (3.2.3)
# Requirement already satisfied: bleach in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (6.3.0)
# Requirement already satisfied: charset-normalizer in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (3.4.2)
# Requirement already satisfied: protobuf in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (5.29.5)
# Requirement already satisfied: python-slugify in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (8.0.4)
# Requirement already satisfied: six>=1.10 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (1.17.0)
# Requirement already satisfied: text-unidecode in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (2.5.0)
# Requirement already satisfied: webencodings in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from kaggle>=1.7.4.5) (0.5.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.21.0) (1.20.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.6) (0.46.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sajjan/.local/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets>=2.21.0) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets>=2.21.0) (1.3.1)
# Requirement already satisfied: jinja2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from torch->timm>=1.0.15) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from sympy==1.13.1->torch->timm>=1.0.15) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sajjan/.conda/envs/myenv/lib/python3.10/site-packages (from jinja2->torch->timm>=1.0.15) (3.0.2)
# Package installation complete.

# %%
from pathlib import Path
import sys
import time
import os
from IPython.display import display
NOTEBOOK_DIR = Path.cwd().resolve()
if str(NOTEBOOK_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_DIR))
from assignment2_gpu_split_module import *
# Out:
# 2026-03-21 01:28:36.688594: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-21 01:28:36.765943: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Project root: /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04
# Device: cuda
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# GPU name: NVIDIA H100 NVL
# cifar10              -> https://www.cs.toronto.edu/~kriz/cifar.html
# fashion_mnist        -> https://github.com/zalandoresearch/fashion-mnist
# imagenet100_hf       -> https://huggingface.co/datasets/clane9/imagenet-100
# imagenet100_kaggle   -> https://www.kaggle.com/datasets/ambityga/imagenet100
# imagecorruptions     -> https://github.com/bethgelab/imagecorruptions
# robustness_repo      -> https://github.com/hendrycks/robustness
# - input size: `224`
# - policy K values: `1, 3, 5, 10, 15`
# - backbones: `vgg16_bn, resnet50, convnext_tiny, vit_base_patch16_224`

# %%
PAIR_DATASET = "fashion_mnist"
PAIR_MODEL = "vit"
TARGET_BATCH_SIZE = 200
IMAGENET100_SOURCE = "local"
IMAGENET100_ROOT = ROOT / "data" / "imagenet100"
TRAIN_PRETRAINED = False
USE_TORCH_COMPILE = True
RUN_REQUIRED_VISUALS = True
RUN_OPTIONAL_FEATURE_PERTURBATION = False
NUM_WORKERS = min(12, os.cpu_count() or 4)

print("PAIR_DATASET =", PAIR_DATASET)
print("PAIR_MODEL =", PAIR_MODEL)
print("TARGET_BATCH_SIZE =", TARGET_BATCH_SIZE)
print("IMAGENET100_ROOT =", IMAGENET100_ROOT)
print("USE_TORCH_COMPILE =", USE_TORCH_COMPILE)
print("NUM_WORKERS =", NUM_WORKERS)
print("COMMON_CORRUPTIONS =", COMMON_CORRUPTIONS)
# Out:
# PAIR_DATASET = fashion_mnist
# PAIR_MODEL = vit
# TARGET_BATCH_SIZE = 200
# IMAGENET100_ROOT = /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/data/imagenet100
# USE_TORCH_COMPILE = True
# NUM_WORKERS = 12
# COMMON_CORRUPTIONS = ['gaussian_noise', 'motion_blur', 'fog', 'brightness', 'jpeg_compression']

# %%
# Mark the start time for the full experiment loop
run_start_time = time.time()

# Main function: passes all hyperparameters into the training/eval wrapper
result = run_single_pair_job(
    dataset_name=PAIR_DATASET,
    model_name=PAIR_MODEL,
    target_batch_size=TARGET_BATCH_SIZE,
    imagenet100_source=IMAGENET100_SOURCE,
    imagenet100_root=IMAGENET100_ROOT,
    train_pretrained=TRAIN_PRETRAINED,
    use_torch_compile=USE_TORCH_COMPILE,
    run_required_visuals=RUN_REQUIRED_VISUALS,
    run_optional_feature_perturbation=RUN_OPTIONAL_FEATURE_PERTURBATION,
    num_workers=NUM_WORKERS,
)

# Convert total runtime to hours (useful for the lab log)
elapsed_hours = (time.time() - run_start_time) / 3600.0
print(f"\nFinished in {elapsed_hours:.2f} hours")

# Render results tables in the notebook interface
display(result["summary_df"])           # Overall metrics (Acc, Loss, etc.)
display(result["clean_rows_df"])         # Results on standard (unmodified) data
display(result["best_corrupt_rows_df"])  # Robustness/OOD test results
display(result["comparison_df"])         # Model vs Model performance delta

# Check if visuals exist before trying to render plots/images
if not result["visuals_df"].empty:
    display(result["visuals_df"])
# Out:
# Auto batch-size probe succeeded with batch_size=200 | memory={'allocated_gb': 1.456, 'reserved_gb': 1.914, 'max_allocated_gb': 13.479}
# ====================================================================================================
# Running single GPU pair: fashion_mnist + vit
# Chosen batch size: 200
# torch.compile enabled: True
# num_workers: 12
# ====================================================================================================
# torch.compile enabled for this run.
# Epoch 1/25 | training...
# Epoch 1/25 | clean validation...
# Epoch 1/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 1, 'train_loss': 1.628553714354833, 'train_acc': 0.3861041666666667, 'lr': 0.0002988172051971717, 'time_sec': 47.421945571899414, 'val_acc__clean': 0.564, 'val_acc__gaussian_noise': 0.5370833333333334, 'val_acc__motion_blur': 0.5686666666666667, 'val_acc__fog': 0.1235, 'val_acc__brightness': 0.15475, 'val_acc__jpeg_compression': 0.5626666666666666, 'val_acc__corr_k1_s2': 0.5370833333333334, 'val_acc__corr_k3_s2': 0.40975, 'val_acc__corr_k5_s2': 0.3893333333333333}
# Epoch 2/25 | training...
# Epoch 2/25 | clean validation...
# Epoch 2/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 2, 'train_loss': 0.9368474451204141, 'train_acc': 0.642375, 'lr': 0.0002952874741692947, 'time_sec': 43.65811038017273, 'val_acc__clean': 0.6968333333333333, 'val_acc__gaussian_noise': 0.6936666666666667, 'val_acc__motion_blur': 0.6960833333333334, 'val_acc__fog': 0.15283333333333332, 'val_acc__brightness': 0.18325, 'val_acc__jpeg_compression': 0.6961666666666667, 'val_acc__corr_k1_s2': 0.6936666666666667, 'val_acc__corr_k3_s2': 0.5141944444444445, 'val_acc__corr_k5_s2': 0.48440000000000005}
# Epoch 3/25 | training...
# Epoch 3/25 | clean validation...
# Epoch 3/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 3, 'train_loss': 0.747045345356067, 'train_acc': 0.7195, 'lr': 0.0002894664728832377, 'time_sec': 57.737486600875854, 'val_acc__clean': 0.7654166666666666, 'val_acc__gaussian_noise': 0.7485, 'val_acc__motion_blur': 0.7628333333333334, 'val_acc__fog': 0.156, 'val_acc__brightness': 0.2970833333333333, 'val_acc__jpeg_compression': 0.76175, 'val_acc__corr_k1_s2': 0.7485, 'val_acc__corr_k3_s2': 0.5557777777777778, 'val_acc__corr_k5_s2': 0.5452333333333333}
# Epoch 4/25 | training...
# Epoch 4/25 | clean validation...
# Epoch 4/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 4, 'train_loss': 0.6537279749910037, 'train_acc': 0.7546875, 'lr': 0.00028144600200657956, 'time_sec': 64.46919870376587, 'val_acc__clean': 0.7795, 'val_acc__gaussian_noise': 0.7665833333333333, 'val_acc__motion_blur': 0.7765, 'val_acc__fog': 0.16283333333333333, 'val_acc__brightness': 0.39, 'val_acc__jpeg_compression': 0.7770833333333333, 'val_acc__corr_k1_s2': 0.7665833333333333, 'val_acc__corr_k3_s2': 0.5686388888888888, 'val_acc__corr_k5_s2': 0.5746}
# Epoch 5/25 | training...
# Epoch 5/25 | clean validation...
# Epoch 5/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 5, 'train_loss': 0.6062235741565625, 'train_acc': 0.773125, 'lr': 0.00027135254915624217, 'time_sec': 66.49742126464844, 'val_acc__clean': 0.7965833333333333, 'val_acc__gaussian_noise': 0.7921666666666667, 'val_acc__motion_blur': 0.8068333333333333, 'val_acc__fog': 0.16508333333333333, 'val_acc__brightness': 0.37066666666666664, 'val_acc__jpeg_compression': 0.79725, 'val_acc__corr_k1_s2': 0.7921666666666667, 'val_acc__corr_k3_s2': 0.5880277777777777, 'val_acc__corr_k5_s2': 0.5864}
# Epoch 6/25 | training...
# Epoch 6/25 | clean validation...
# Epoch 6/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 6, 'train_loss': 0.5573593840003014, 'train_acc': 0.7927291666666667, 'lr': 0.0002593452941132118, 'time_sec': 62.4246027469635, 'val_acc__clean': 0.82, 'val_acc__gaussian_noise': 0.8078333333333333, 'val_acc__motion_blur': 0.8225833333333333, 'val_acc__fog': 0.14408333333333334, 'val_acc__brightness': 0.4410833333333333, 'val_acc__jpeg_compression': 0.81825, 'val_acc__corr_k1_s2': 0.8078333333333333, 'val_acc__corr_k3_s2': 0.5915, 'val_acc__corr_k5_s2': 0.6067666666666667}
# Epoch 7/25 | training...
# Epoch 7/25 | clean validation...
# Epoch 7/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 7, 'train_loss': 0.5275619541605313, 'train_acc': 0.8032083333333333, 'lr': 0.00024561359846230347, 'time_sec': 54.768550634384155, 'val_acc__clean': 0.8199166666666666, 'val_acc__gaussian_noise': 0.8131666666666667, 'val_acc__motion_blur': 0.8300833333333333, 'val_acc__fog': 0.14766666666666667, 'val_acc__brightness': 0.45258333333333334, 'val_acc__jpeg_compression': 0.81775, 'val_acc__corr_k1_s2': 0.8131666666666667, 'val_acc__corr_k3_s2': 0.5969722222222222, 'val_acc__corr_k5_s2': 0.6122500000000001}
# Epoch 8/25 | training...
# Epoch 8/25 | clean validation...
# Epoch 8/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 8, 'train_loss': 0.49757105819880965, 'train_acc': 0.8147708333333333, 'lr': 0.0002303740192468495, 'time_sec': 59.33530020713806, 'val_acc__clean': 0.8196666666666667, 'val_acc__gaussian_noise': 0.8138333333333333, 'val_acc__motion_blur': 0.8195833333333333, 'val_acc__fog': 0.16791666666666666, 'val_acc__brightness': 0.47683333333333333, 'val_acc__jpeg_compression': 0.8180833333333334, 'val_acc__corr_k1_s2': 0.8138333333333333, 'val_acc__corr_k3_s2': 0.6004444444444444, 'val_acc__corr_k5_s2': 0.6192500000000001}
# Epoch 9/25 | training...
# Epoch 9/25 | clean validation...
# Epoch 9/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 9, 'train_loss': 0.4804069654395183, 'train_acc': 0.82275, 'lr': 0.0002138668937347609, 'time_sec': 55.08846879005432, 'val_acc__clean': 0.8409166666666666, 'val_acc__gaussian_noise': 0.8259166666666666, 'val_acc__motion_blur': 0.8444166666666667, 'val_acc__fog': 0.141, 'val_acc__brightness': 0.35925, 'val_acc__jpeg_compression': 0.8405, 'val_acc__corr_k1_s2': 0.8259166666666666, 'val_acc__corr_k3_s2': 0.6037777777777777, 'val_acc__corr_k5_s2': 0.6022166666666666}
# Epoch 10/25 | training...
# Epoch 10/25 | clean validation...
# Epoch 10/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 10, 'train_loss': 0.4534649937103192, 'train_acc': 0.830875, 'lr': 0.0001963525491562421, 'time_sec': 57.757309436798096, 'val_acc__clean': 0.8421666666666666, 'val_acc__gaussian_noise': 0.8241666666666667, 'val_acc__motion_blur': 0.8344166666666667, 'val_acc__fog': 0.15275, 'val_acc__brightness': 0.4005, 'val_acc__jpeg_compression': 0.8405833333333333, 'val_acc__corr_k1_s2': 0.8241666666666667, 'val_acc__corr_k3_s2': 0.6037777777777779, 'val_acc__corr_k5_s2': 0.6104833333333334}
# Epoch 11/25 | training...
# Epoch 11/25 | clean validation...
# Epoch 11/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 11, 'train_loss': 0.44654603314896424, 'train_acc': 0.8327916666666667, 'lr': 0.00017810719718785873, 'time_sec': 61.99013066291809, 'val_acc__clean': 0.8529166666666667, 'val_acc__gaussian_noise': 0.8341666666666666, 'val_acc__motion_blur': 0.8494166666666667, 'val_acc__fog': 0.16358333333333333, 'val_acc__brightness': 0.5204166666666666, 'val_acc__jpeg_compression': 0.8530833333333333, 'val_acc__corr_k1_s2': 0.8341666666666666, 'val_acc__corr_k3_s2': 0.6157222222222223, 'val_acc__corr_k5_s2': 0.6441333333333333}
# Epoch 12/25 | training...
# Epoch 12/25 | clean validation...
# Epoch 12/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 12, 'train_loss': 0.4121376652270555, 'train_acc': 0.8457708333333334, 'lr': 0.00015941857792939703, 'time_sec': 56.8402419090271, 'val_acc__clean': 0.8585, 'val_acc__gaussian_noise': 0.834, 'val_acc__motion_blur': 0.8559166666666667, 'val_acc__fog': 0.16025, 'val_acc__brightness': 0.487, 'val_acc__jpeg_compression': 0.8560833333333333, 'val_acc__corr_k1_s2': 0.834, 'val_acc__corr_k3_s2': 0.6167222222222222, 'val_acc__corr_k5_s2': 0.6386499999999999}
# Epoch 13/25 | training...
# Epoch 13/25 | clean validation...
# Epoch 13/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 13, 'train_loss': 0.4032868998746077, 'train_acc': 0.8487708333333334, 'lr': 0.00014058142207060302, 'time_sec': 40.274370431900024, 'val_acc__clean': 0.8668333333333333, 'val_acc__gaussian_noise': 0.84875, 'val_acc__motion_blur': 0.8681666666666666, 'val_acc__fog': 0.12491666666666666, 'val_acc__brightness': 0.48541666666666666, 'val_acc__jpeg_compression': 0.8660833333333333, 'val_acc__corr_k1_s2': 0.84875, 'val_acc__corr_k3_s2': 0.6139444444444444, 'val_acc__corr_k5_s2': 0.6386666666666667}
# Epoch 14/25 | training...
# Epoch 14/25 | clean validation...
# Epoch 14/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 14, 'train_loss': 0.3836096342653036, 'train_acc': 0.8585625, 'lr': 0.00012189280281214133, 'time_sec': 46.021241903305054, 'val_acc__clean': 0.86325, 'val_acc__gaussian_noise': 0.83225, 'val_acc__motion_blur': 0.8691666666666666, 'val_acc__fog': 0.18966666666666668, 'val_acc__brightness': 0.5515833333333333, 'val_acc__jpeg_compression': 0.8628333333333333, 'val_acc__corr_k1_s2': 0.83225, 'val_acc__corr_k3_s2': 0.6303611111111111, 'val_acc__corr_k5_s2': 0.6611}
# Epoch 15/25 | training...
# Epoch 15/25 | clean validation...
# Epoch 15/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 15, 'train_loss': 0.3643654273822904, 'train_acc': 0.8647916666666666, 'lr': 0.00010364745084375795, 'time_sec': 48.389925718307495, 'val_acc__clean': 0.8778333333333334, 'val_acc__gaussian_noise': 0.8635833333333334, 'val_acc__motion_blur': 0.8835833333333334, 'val_acc__fog': 0.1755, 'val_acc__brightness': 0.51125, 'val_acc__jpeg_compression': 0.8764166666666666, 'val_acc__corr_k1_s2': 0.8635833333333334, 'val_acc__corr_k3_s2': 0.640888888888889, 'val_acc__corr_k5_s2': 0.6620666666666667}
# Epoch 16/25 | training...
# Epoch 16/25 | clean validation...
# Epoch 16/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 16, 'train_loss': 0.35441734263052543, 'train_acc': 0.8672083333333334, 'lr': 8.61331062652391e-05, 'time_sec': 46.3374137878418, 'val_acc__clean': 0.8809166666666667, 'val_acc__gaussian_noise': 0.8518333333333333, 'val_acc__motion_blur': 0.87925, 'val_acc__fog': 0.14075, 'val_acc__brightness': 0.52525, 'val_acc__jpeg_compression': 0.8790833333333333, 'val_acc__corr_k1_s2': 0.8518333333333333, 'val_acc__corr_k3_s2': 0.6239444444444444, 'val_acc__corr_k5_s2': 0.6552333333333333}
# Epoch 17/25 | training...
# Epoch 17/25 | clean validation...
# Epoch 17/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 17, 'train_loss': 0.33093956566105287, 'train_acc': 0.8755416666666667, 'lr': 6.962598075315047e-05, 'time_sec': 43.26763129234314, 'val_acc__clean': 0.882, 'val_acc__gaussian_noise': 0.8415833333333333, 'val_acc__motion_blur': 0.8831666666666667, 'val_acc__fog': 0.1855, 'val_acc__brightness': 0.4989166666666667, 'val_acc__jpeg_compression': 0.8798333333333334, 'val_acc__corr_k1_s2': 0.8415833333333333, 'val_acc__corr_k3_s2': 0.63675, 'val_acc__corr_k5_s2': 0.6578}
# Epoch 18/25 | training...
# Epoch 18/25 | clean validation...
# Epoch 18/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 18, 'train_loss': 0.32119554144640766, 'train_acc': 0.8793541666666667, 'lr': 5.4386401537696536e-05, 'time_sec': 37.74520707130432, 'val_acc__clean': 0.8868333333333334, 'val_acc__gaussian_noise': 0.86325, 'val_acc__motion_blur': 0.8878333333333334, 'val_acc__fog': 0.19541666666666666, 'val_acc__brightness': 0.548, 'val_acc__jpeg_compression': 0.8866666666666667, 'val_acc__corr_k1_s2': 0.86325, 'val_acc__corr_k3_s2': 0.6488333333333333, 'val_acc__corr_k5_s2': 0.6762333333333334}
# Epoch 19/25 | training...
# Epoch 19/25 | clean validation...
# Epoch 19/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 19, 'train_loss': 0.3059820434078574, 'train_acc': 0.8864791666666667, 'lr': 4.06547058867883e-05, 'time_sec': 39.455968379974365, 'val_acc__clean': 0.8891666666666667, 'val_acc__gaussian_noise': 0.8645, 'val_acc__motion_blur': 0.8875, 'val_acc__fog': 0.16558333333333333, 'val_acc__brightness': 0.491, 'val_acc__jpeg_compression': 0.88775, 'val_acc__corr_k1_s2': 0.8645, 'val_acc__corr_k3_s2': 0.6391944444444445, 'val_acc__corr_k5_s2': 0.6592666666666667}
# Epoch 20/25 | training...
# Epoch 20/25 | clean validation...
# Epoch 20/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 20, 'train_loss': 0.2922620008389155, 'train_acc': 0.8896875, 'lr': 2.86474508437579e-05, 'time_sec': 33.03875541687012, 'val_acc__clean': 0.895, 'val_acc__gaussian_noise': 0.87025, 'val_acc__motion_blur': 0.8936666666666667, 'val_acc__fog': 0.17883333333333334, 'val_acc__brightness': 0.48841666666666667, 'val_acc__jpeg_compression': 0.891, 'val_acc__corr_k1_s2': 0.87025, 'val_acc__corr_k3_s2': 0.6475833333333334, 'val_acc__corr_k5_s2': 0.6644333333333334}
# Epoch 21/25 | training...
# Epoch 21/25 | clean validation...
# Epoch 21/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 21, 'train_loss': 0.28077960945665836, 'train_acc': 0.8945208333333333, 'lr': 1.8553997993420465e-05, 'time_sec': 46.22997212409973, 'val_acc__clean': 0.8990833333333333, 'val_acc__gaussian_noise': 0.8751666666666666, 'val_acc__motion_blur': 0.8988333333333334, 'val_acc__fog': 0.18483333333333332, 'val_acc__brightness': 0.48525, 'val_acc__jpeg_compression': 0.89475, 'val_acc__corr_k1_s2': 0.8751666666666666, 'val_acc__corr_k3_s2': 0.6529444444444444, 'val_acc__corr_k5_s2': 0.6677666666666667}
# Epoch 22/25 | training...
# Epoch 22/25 | clean validation...
# Epoch 22/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 22, 'train_loss': 0.27068366718788944, 'train_acc': 0.8980208333333334, 'lr': 1.05335271167623e-05, 'time_sec': 52.15582585334778, 'val_acc__clean': 0.8959166666666667, 'val_acc__gaussian_noise': 0.8681666666666666, 'val_acc__motion_blur': 0.8976666666666666, 'val_acc__fog': 0.18116666666666667, 'val_acc__brightness': 0.5268333333333334, 'val_acc__jpeg_compression': 0.8950833333333333, 'val_acc__corr_k1_s2': 0.8681666666666666, 'val_acc__corr_k3_s2': 0.6489999999999999, 'val_acc__corr_k5_s2': 0.6737833333333334}
# Epoch 23/25 | training...
# Epoch 23/25 | clean validation...
# Epoch 23/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 23, 'train_loss': 0.2633718833327293, 'train_acc': 0.9012083333333333, 'lr': 4.712525830705356e-06, 'time_sec': 34.95076894760132, 'val_acc__clean': 0.9013333333333333, 'val_acc__gaussian_noise': 0.8745, 'val_acc__motion_blur': 0.90425, 'val_acc__fog': 0.18783333333333332, 'val_acc__brightness': 0.50675, 'val_acc__jpeg_compression': 0.8956666666666667, 'val_acc__corr_k1_s2': 0.8745, 'val_acc__corr_k3_s2': 0.6555277777777778, 'val_acc__corr_k5_s2': 0.6738000000000001}
# Epoch 24/25 | training...
# Epoch 24/25 | clean validation...
# Epoch 24/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 24, 'train_loss': 0.25563300028443336, 'train_acc': 0.9034375, 'lr': 1.1827948028283355e-06, 'time_sec': 44.85541367530823, 'val_acc__clean': 0.9023333333333333, 'val_acc__gaussian_noise': 0.8771666666666667, 'val_acc__motion_blur': 0.9033333333333333, 'val_acc__fog': 0.17983333333333335, 'val_acc__brightness': 0.5083333333333333, 'val_acc__jpeg_compression': 0.8999166666666667, 'val_acc__corr_k1_s2': 0.8771666666666667, 'val_acc__corr_k3_s2': 0.6534444444444444, 'val_acc__corr_k5_s2': 0.6737166666666667}
# Epoch 25/25 | training...
# Epoch 25/25 | clean validation...
# Epoch 25/25 | corrupted validation over 5 corruption types...
#   validating corruption: gaussian_noise
#   validating corruption: motion_blur
#   validating corruption: fog
#   validating corruption: brightness
#   validating corruption: jpeg_compression
# {'epoch': 25, 'train_loss': 0.25456102918833495, 'train_acc': 0.9042916666666667, 'lr': 0.0, 'time_sec': 35.811970472335815, 'val_acc__clean': 0.90275, 'val_acc__gaussian_noise': 0.8746666666666667, 'val_acc__motion_blur': 0.90725, 'val_acc__fog': 0.18316666666666667, 'val_acc__brightness': 0.50475, 'val_acc__jpeg_compression': 0.8991666666666667, 'val_acc__corr_k1_s2': 0.8746666666666667, 'val_acc__corr_k3_s2': 0.6550277777777778, 'val_acc__corr_k5_s2': 0.6738}
# Saved plots to: /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/plots/clean
# Saved plots to: /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/plots/corr_k5_s2
#
# Finished in 1.03 hours
#          dataset model    selector selector_type  best_epoch  best_val_score  \
# 0  fashion_mnist   vit       clean         clean          25        0.902750
# 1  fashion_mnist   vit  corr_k1_s2       corrupt          24        0.877167
# 2  fashion_mnist   vit  corr_k3_s2       corrupt          23        0.655528
# 3  fashion_mnist   vit  corr_k5_s2       corrupt          18        0.676233
#
#    num_val_corruptions                               val_corruption_names  \
# 0                    0
# 1                    1                                     gaussian_noise
# 2                    3                   gaussian_noise, motion_blur, fog
# 3                    5  gaussian_noise, motion_blur, fog, brightness, ...
#
#    val_corruption_severity  test_clean_acc  test_corrupt_mean_acc  \
# 0                        0          0.9001                0.67070
# 1                        2          0.9006                0.67058
# 2                        2          0.8974                0.67028
# 3                        2          0.8846                0.67250
#
#    robustness_gap                                     experiment_dir  \
# 0         0.22940  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 1         0.23002  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 2         0.22712  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 3         0.21210  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#
#                                      checkpoint_path
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 1  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 2  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 3  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#          dataset model selector selector_type  best_epoch  best_val_score  \
# 0  fashion_mnist   vit    clean         clean          25         0.90275
#
#    num_val_corruptions val_corruption_names  val_corruption_severity  \
# 0                    0                                             0
#
#    test_clean_acc  test_corrupt_mean_acc  robustness_gap  \
# 0          0.9001                 0.6707          0.2294
#
#                                       experiment_dir  \
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#
#                                      checkpoint_path
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#          dataset model    selector selector_type  best_epoch  best_val_score  \
# 0  fashion_mnist   vit  corr_k5_s2       corrupt          18        0.676233
#
#    num_val_corruptions                               val_corruption_names  \
# 0                    5  gaussian_noise, motion_blur, fog, brightness, ...
#
#    val_corruption_severity  test_clean_acc  test_corrupt_mean_acc  \
# 0                        2          0.8846                 0.6725
#
#    robustness_gap                                     experiment_dir  \
# 0          0.2121  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#
#                                      checkpoint_path
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#          dataset model selector_clean_selector selector_type_clean_selector  \
# 0  fashion_mnist   vit                   clean                        clean
#
#    best_epoch_clean_selector  best_val_score_clean_selector  \
# 0                         25                        0.90275
#
#    num_val_corruptions_clean_selector val_corruption_names_clean_selector  \
# 0                                   0
#
#    val_corruption_severity_clean_selector  test_clean_acc_clean_selector  ...  \
# 0                                       0                         0.9001  ...
#
#    best_epoch_best_corrupt_selector  best_val_score_best_corrupt_selector  \
# 0                                18                              0.676233
#
#   num_val_corruptions_best_corrupt_selector  \
# 0                                         5
#
#           val_corruption_names_best_corrupt_selector  \
# 0  gaussian_noise, motion_blur, fog, brightness, ...
#
#   val_corruption_severity_best_corrupt_selector  \
# 0                                             2
#
#   test_clean_acc_best_corrupt_selector  \
# 0                               0.8846
#
#    test_corrupt_mean_acc_best_corrupt_selector  \
# 0                                       0.6725
#
#    robustness_gap_best_corrupt_selector  \
# 0                                0.2121
#
#                 experiment_dir_best_corrupt_selector  \
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#
#                checkpoint_path_best_corrupt_selector
# 0  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
#
# [1 rows x 26 columns]
#      selector                                           plot_dir
# 0       clean  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...
# 1  corr_k5_s2  /data/Sajjan_Singh/cv_assign_04/cv_assign_04_g...

# %%
print("Saved files:")
print(Path(result["experiment_dir"]) / "selector_summary.csv")
print(Path(result["experiment_dir"]) / "pair_all_selectors.csv")
print(Path(result["experiment_dir"]) / "pair_clean_rows.csv")
print(Path(result["experiment_dir"]) / "pair_best_corrupt_rows.csv")
print(Path(result["experiment_dir"]) / "pair_clean_vs_best_corrupt_comparison.csv")
# Out:
# Saved files:
# /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/selector_summary.csv
# /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/pair_all_selectors.csv
# /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/pair_clean_rows.csv
# /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/pair_best_corrupt_rows.csv
# /data/Sajjan_Singh/cv_assign_04/cv_assign_04_gpu_split_local_fast5/cv_assign_04_gpu_split_local_fast5/cv_assign_04/checkpoints/fashion_mnist_vit_seed42/pair_clean_vs_best_corrupt_comparison.csv
